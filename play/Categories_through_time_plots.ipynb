# %%
import pandas as pd
from scipy import stats 
import numpy as np
import json

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from collections import defaultdict

#change to appropriate path
results_path = "/Users/mark/Desktop/wiki_v4/"
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
#load Categories through time
temp_store_path = "/Users/mark/Desktop/temp_data/"
with open(temp_store_path + "categories_decades_transformed.json", "r") as f:
    categories_decades = json.load(f)

# %%
#plot top 10 categories

categories_df = pd.DataFrame.from_dict(categories_decades)

# %%
categories_df.tail(1).transpose().sort_values('2010', ascending=False).head(20)
# Out:
#                                  2010
# The Arts                       759483
# Relative position              546074
# Sport                          474968
# Farming                        445691
# Navigation                     422161
# The body                       412295
# Food                           393021
# Number                         384227
# Knowledge                      380096
# Entertainment                  370601
# Inhabited place                352682
# Equipment                      338614
# Ill-health                     333439
# Rule/government                320633
# Mammals                        312023
# Clothing                       304661
# Motion in a certain direction  301321
# Physics                        299489
# Materials                      295080
# Wholeness                      278417

# %%
coln_bool = [c in list(categories_df.tail(1).transpose().sort_values('2010', ascending=False).head(10).index) for c in categories_df.columns.values]

# %%
categories_df.transpose()[coln_bool].transpose().plot()
plt.title("Top 10 Categories")

# %% [markdown]
# ## Detrended Categories
# * removing trend of word appearance in the OED

# %%
pandas.read_json(temp_store_path + "categories_decades_de.json")
